# %% [markdown]
# # Hello, KAN!

# %% [markdown]
# ### Kolmogorov-Arnold representation theorem

# %% [markdown]
# Kolmogorov-Arnold representation theorem states that if $f$ is a multivariate continuous function
# on a bounded domain, then it can be written as a finite composition of continuous functions of a
# single variable and the binary operation of addition. More specifically, for a smooth $f : [0,1]^n \to \mathbb{R}$,
#
#
# $$f(x) = f(x_1,...,x_n)=\sum_{q=1}^{2n+1}\Phi_q(\sum_{p=1}^n \phi_{q,p}(x_p))$$
#
# where $\phi_{q,p}:[0,1]\to\mathbb{R}$ and $\Phi_q:\mathbb{R}\to\mathbb{R}$. In a sense, they showed that the only true multivariate function is addition, since every other function can be written using univariate functions and sum. However, this 2-Layer width-$(2n+1)$ Kolmogorov-Arnold representation may not be smooth due to its limited expressive power. We augment its expressive power by generalizing it to arbitrary depths and widths.

# %% [markdown]
# ### Kolmogorov-Arnold Network (KAN)

# %% [markdown]
# The Kolmogorov-Arnold representation can be written in matrix form
#
# $$f(x)={\bf \Phi}_{\rm out}\circ{\bf \Phi}_{\rm in}\circ {\bf x}$$
#
# where
#
# $${\bf \Phi}_{\rm in}= \begin{pmatrix} \phi_{1,1}(\cdot) & \cdots & \phi_{1,n}(\cdot) \\ \vdots & & \vdots \\ \phi_{2n+1,1}(\cdot) & \cdots & \phi_{2n+1,n}(\cdot) \end{pmatrix},\quad {\bf \Phi}_{\rm out}=\begin{pmatrix} \Phi_1(\cdot) & \cdots & \Phi_{2n+1}(\cdot)\end{pmatrix}$$

# %% [markdown]
# We notice that both ${\bf \Phi}_{\rm in}$ and ${\bf \Phi}_{\rm out}$ are special cases of the following function matrix ${\bf \Phi}$ (with $n_{\rm in}$ inputs, and $n_{\rm out}$ outputs), we call a Kolmogorov-Arnold layer:
#
# $${\bf \Phi}= \begin{pmatrix} \phi_{1,1}(\cdot) & \cdots & \phi_{1,n_{\rm in}}(\cdot) \\ \vdots & & \vdots \\ \phi_{n_{\rm out},1}(\cdot) & \cdots & \phi_{n_{\rm out},n_{\rm in}}(\cdot) \end{pmatrix}$$
#
# ${\bf \Phi}_{\rm in}$ corresponds to $n_{\rm in}=n, n_{\rm out}=2n+1$, and ${\bf \Phi}_{\rm out}$ corresponds to $n_{\rm in}=2n+1, n_{\rm out}=1$.

# %% [markdown]
# After defining the layer, we can construct a Kolmogorov-Arnold network simply by stacking layers! Let's say we have $L$ layers, with the $l^{\rm th}$ layer ${\bf \Phi}_l$ have shape $(n_{l+1}, n_{l})$. Then the whole network is
#
# $${\rm KAN}({\bf x})={\bf \Phi}_{L-1}\circ\cdots \circ{\bf \Phi}_1\circ{\bf \Phi}_0\circ {\bf x}$$

# %% [markdown]
# In constrast, a Multi-Layer Perceptron is interleaved by linear layers ${\bf W}_l$ and nonlinearities $\sigma$:
#
# $${\rm MLP}({\bf x})={\bf W}_{L-1}\circ\sigma\circ\cdots\circ {\bf W}_1\circ\sigma\circ {\bf W}_0\circ {\bf x}$$

# %% [markdown]
# A KAN can be easily visualized. (1) A KAN is simply stack of KAN layers. (2) Each KAN layer can be visualized as a fully-connected layer, with a 1D function placed on each edge. Let's see an example below.

# %% [markdown]
# ### Get started with KANs

# %% [markdown]
# Initialize KAN

# %%
from kan import *
# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[2,5,1], grid=5, k=3, seed=0)

# %% [markdown]
# Create dataset

# %%
# create dataset f(x,y) = exp(sin(pi*x)+y^2)
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2)
dataset['train_input'].shape, dataset['train_label'].shape
# Out:
# (torch.Size([1000, 2]), torch.Size([1000, 1]))

# %% [markdown]
# Plot KAN at initialization

# %%
# plot KAN at initialization
model(dataset['train_input'])
model.plot(beta=100)

# %% [markdown]
# Train KAN with sparsity regularization

# %%
# train the model
model.train(dataset, opt="LBFGS", steps=20, lamb=0.01, lamb_entropy=10.);
# Out:
# train loss: 1.18e-01 | test loss: 1.23e-01 | reg: 2.35e+01 : 100%|██| 20/20 [00:06<00:00,  3.08it/s]

# %% [markdown]
# Plot trained KAN

# %%
model.plot()

# %% [markdown]
# Prune KAN and replot (keep the original shape)

# %%
model.prune()
model.plot(mask=True)

# %% [markdown]
# Prune KAN and replot (get a smaller shape)

# %%
model = model.prune()
model(dataset['train_input'])
model.plot()

# %% [markdown]
# Continue training and replot

# %%
model.train(dataset, opt="LBFGS", steps=50)
# Out:
# train loss: 2.41e-03 | test loss: 2.40e-03 | reg: 4.75e+00 : 100%|██| 50/50 [00:10<00:00,  4.75it/s]
# {'train_loss': [array(0.06952397, dtype=float32),
#   array(0.03500791, dtype=float32),
#   array(0.02927636, dtype=float32),
#   array(0.02263142, dtype=float32),
#   array(0.02080087, dtype=float32),
#   array(0.01768658, dtype=float32),
#   array(0.01536743, dtype=float32),
#   array(0.01363646, dtype=float32),
#   array(0.01217277, dtype=float32),
#   array(0.00932258, dtype=float32),
#   array(0.00812579, dtype=float32),
#   array(0.00683222, dtype=float32),
#   array(0.00589234, dtype=float32),
#   array(0.00535731, dtype=float32),
#   array(0.00418212, dtype=float32),
#   array(0.00401392, dtype=float32),
#   array(0.00389285, dtype=float32),
#   array(0.00379265, dtype=float32),
#   array(0.00377113, dtype=float32),
#   array(0.00374392, dtype=float32),
#   array(0.00370286, dtype=float32),
#   array(0.00366175, dtype=float32),
#   array(0.00361365, dtype=float32),
#   array(0.00356474, dtype=float32),
#   array(0.00347248, dtype=float32),
#   array(0.00340055, dtype=float32),
#   array(0.00330832, dtype=float32),
#   array(0.00320291, dtype=float32),
#   array(0.00309563, dtype=float32),
#   array(0.00306539, dtype=float32),
#   array(0.00307484, dtype=float32),
#   array(0.00303137, dtype=float32),
#   array(0.00296947, dtype=float32),
#   array(0.00291574, dtype=float32),
#   array(0.00285898, dtype=float32),
#   array(0.00284247, dtype=float32),
#   array(0.00280194, dtype=float32),
#   array(0.00275687, dtype=float32),
#   array(0.00273887, dtype=float32),
#   array(0.00269609, dtype=float32),
#   array(0.00268111, dtype=float32),
#   array(0.00264722, dtype=float32),
#   array(0.00258147, dtype=float32),
#   array(0.00253012, dtype=float32),
#   array(0.00251156, dtype=float32),
#   array(0.00251838, dtype=float32),
#   array(0.00248274, dtype=float32),
#   array(0.00244447, dtype=float32),
#   array(0.00241946, dtype=float32),
#   array(0.00241075, dtype=float32)],
#  'test_loss': [array(0.07252776, dtype=float32),
#   array(0.03451301, dtype=float32),
#   array(0.02829242, dtype=float32),
#   array(0.02301053, dtype=float32),
#   array(0.0206884, dtype=float32),
#   array(0.01748048, dtype=float32),
#   array(0.01535173, dtype=float32),
#   array(0.01350545, dtype=float32),
#   array(0.01205781, dtype=float32),
#   array(0.0095697, dtype=float32),
#   array(0.00873177, dtype=float32),
#   array(0.00734147, dtype=float32),
#   array(0.00634672, dtype=float32),
#   array(0.00569125, dtype=float32),
#   array(0.00436517, dtype=float32),
#   array(0.00432541, dtype=float32),
#   array(0.00414348, dtype=float32),
#   array(0.0039608, dtype=float32),
#   array(0.00394911, dtype=float32),
#   array(0.00388921, dtype=float32),
#   array(0.0038404, dtype=float32),
#   array(0.00380386, dtype=float32),
#   array(0.00378709, dtype=float32),
#   array(0.00370293, dtype=float32),
#   array(0.00352297, dtype=float32),
#   array(0.00340195, dtype=float32),
#   array(0.00331331, dtype=float32),
#   array(0.00319538, dtype=float32),
#   array(0.00313276, dtype=float32),
#   array(0.00309212, dtype=float32),
#   array(0.00308154, dtype=float32),
#   array(0.00299199, dtype=float32),
#   array(0.00297526, dtype=float32),
#   array(0.00294475, dtype=float32),
#   array(0.00294541, dtype=float32),
#   array(0.00292593, dtype=float32),
#   array(0.00289956, dtype=float32),
#   array(0.00280778, dtype=float32),
#   array(0.00276117, dtype=float32),
#   array(0.00274713, dtype=float32),
#   array(0.0027314, dtype=float32),
#   array(0.00269196, dtype=float32),
#   array(0.00257851, dtype=float32),
#   array(0.00251885, dtype=float32),
#   array(0.00249379, dtype=float32),
#   array(0.00249581, dtype=float32),
#   array(0.00244378, dtype=float32),
#   array(0.00240584, dtype=float32),
#   array(0.00240477, dtype=float32),
#   array(0.00239508, dtype=float32)],
#  'reg': [array(5.317565, dtype=float32),
#   array(5.130704, dtype=float32),
#   array(4.985098, dtype=float32),
#   array(4.8238087, dtype=float32),
#   array(4.755941, dtype=float32),
#   array(4.9645185, dtype=float32),
#   array(4.912366, dtype=float32),
#   array(4.713298, dtype=float32),
#   array(4.6622224, dtype=float32),
#   array(4.931636, dtype=float32),
#   array(4.8968377, dtype=float32),
#   array(4.885608, dtype=float32),
#   array(4.8315372, dtype=float32),
#   array(4.789418, dtype=float32),
#   array(4.7620177, dtype=float32),
#   array(4.7563753, dtype=float32),
#   array(4.7372746, dtype=float32),
#   array(4.755955, dtype=float32),
#   array(4.7531195, dtype=float32),
#   array(4.745141, dtype=float32),
#   array(4.7294774, dtype=float32),
#   array(4.7206197, dtype=float32),
#   array(4.712137, dtype=float32),
#   array(4.6868334, dtype=float32),
#   array(4.704734, dtype=float32),
#   array(4.7030897, dtype=float32),
#   array(4.6780777, dtype=float32),
#   array(4.6706967, dtype=float32),
#   array(4.6629963, dtype=float32),
#   array(4.6580534, dtype=float32),
#   array(4.692215, dtype=float32),
#   array(4.6934805, dtype=float32),
#   array(4.6726966, dtype=float32),
#   array(4.6687117, dtype=float32),
#   array(4.7031207, dtype=float32),
#   array(4.688201, dtype=float32),
#   array(4.699996, dtype=float32),
#   array(4.6978354, dtype=float32),
#   array(4.6926026, dtype=float32),
#   array(4.690563, dtype=float32),
#   array(4.699068, dtype=float32),
#   array(4.7056823, dtype=float32),
#   array(4.7158384, dtype=float32),
#   array(4.722823, dtype=float32),
#   array(4.72742, dtype=float32),
#   array(4.72611, dtype=float32),
#   array(4.7420444, dtype=float32),
#   array(4.744658, dtype=float32),
#   array(4.7489166, dtype=float32),
#   array(4.7519813, dtype=float32)]}

# %%
model.plot()

# %% [markdown]
# Automatically or manually set activation functions to be symbolic

# %%
mode = "auto" # "manual"

if mode == "manual":
    # manual mode
    model.fix_symbolic(0,0,0,'sin');
    model.fix_symbolic(0,1,0,'x^2');
    model.fix_symbolic(1,0,0,'exp');
elif mode == "auto":
    # automatic mode
    lib = ['x','x^2','x^3','x^4','exp','log','sqrt','tanh','sin','abs']
    model.auto_symbolic(lib=lib)
# Out:
# fixing (0,0,0) with sin, r2=0.9999549984931946
# fixing (0,0,1) with sin, r2=0.9930299520492554
# fixing (0,1,0) with x^2, r2=1.000000238418579
# fixing (0,1,1) with abs, r2=0.8426985740661621
# fixing (1,0,0) with exp, r2=0.9999966025352478
# fixing (1,1,0) with sin, r2=0.7962881922721863

# %% [markdown]
# Continue training to almost machine precision

# %%
model.train(dataset, opt="LBFGS", steps=50)
# Out:
# train loss: 5.28e-05 | test loss: 5.50e-05 | reg: 4.68e+00 : 100%|██| 50/50 [00:05<00:00,  9.43it/s]
# {'train_loss': [array(0.00807266, dtype=float32),
#   array(0.00437369, dtype=float32),
#   array(0.00166832, dtype=float32),
#   array(0.00109233, dtype=float32),
#   array(0.00101946, dtype=float32),
#   array(0.00082054, dtype=float32),
#   array(0.00040134, dtype=float32),
#   array(0.00033083, dtype=float32),
#   array(0.00021586, dtype=float32),
#   array(0.00020455, dtype=float32),
#   array(0.00011521, dtype=float32),
#   array(5.296465e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.2805943e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.2805943e-05, dtype=float32),
#   array(5.2805943e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.2805943e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32),
#   array(5.280594e-05, dtype=float32)],
#  'test_loss': [array(0.00792247, dtype=float32),
#   array(0.00434133, dtype=float32),
#   array(0.00164316, dtype=float32),
#   array(0.00106882, dtype=float32),
#   array(0.0010201, dtype=float32),
#   array(0.00084148, dtype=float32),
#   array(0.00039565, dtype=float32),
#   array(0.00033645, dtype=float32),
#   array(0.00022452, dtype=float32),
#   array(0.000213, dtype=float32),
#   array(0.00012286, dtype=float32),
#   array(5.4807122e-05, dtype=float32),
#   array(5.4997927e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.4997927e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.4997927e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.4997923e-05, dtype=float32),
#   array(5.499792e-05, dtype=float32)],
#  'reg': [array(4.7350206, dtype=float32),
#   array(4.7119164, dtype=float32),
#   array(4.6934905, dtype=float32),
#   array(4.6902676, dtype=float32),
#   array(4.6892023, dtype=float32),
#   array(4.685233, dtype=float32),
#   array(4.6792808, dtype=float32),
#   array(4.6782746, dtype=float32),
#   array(4.6784396, dtype=float32),
#   array(4.6783385, dtype=float32),
#   array(4.6787677, dtype=float32),
#   array(4.678516, dtype=float32),
#   array(4.6785564, dtype=float32),
#   array(4.6785564, dtype=float32),
#   array(4.6785564, dtype=float32),
#   array(4.6785593, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.6785593, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.6785593, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.6785593, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.6785593, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.6785593, dtype=float32),
#   array(4.678559, dtype=float32),
#   array(4.678559, dtype=float32)]}

# %% [markdown]
# Obtain the symbolic formula

# %%
model.symbolic_formula()[0][0]
# Out:
# 1.0*exp(1.0*x_2**2 + 1.0*sin(3.14*x_1))
